# %%
query = f"""
SELECT 
    t.emp_no,
    e.full_name,
    t.from_date AS title_start_date,
    t.to_date AS title_end_date,
    LAG(t.title) OVER (PARTITION BY t.emp_no ORDER BY t.from_date) AS previous_title,
    t.title as current_title,
    CASE 
        WHEN LAG(t.title) OVER (PARTITION BY t.emp_no ORDER BY t.from_date) IS NULL THEN 'Initial Title'
        WHEN t.title <> LAG(t.title) OVER (PARTITION BY t.emp_no ORDER BY t.from_date) THEN 'Promoted'
        ELSE 'No Change'
    END AS promotion_status,
    CASE 
        WHEN t.to_date = '9999-01-01' 
        THEN 'Current'
        ELSE 'Exited'
    END AS employment_status
FROM employee_catalog.silver.titles t
LEFT JOIN employee_catalog.silver.employees e 
ON t.emp_no = e.emp_no
ORDER BY
    1

"""

# %%
promotion_history_df = spark.sql(query)
display(promotion_history_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_no</th><th>full_name</th><th>title_start_date</th><th>title_end_date</th><th>previous_title</th><th>current_title</th><th>promotion_status</th><th>employment_status</th></tr></thead><tbody><tr><td>100000</td><td>Hiroyasu Emden</td><td>1991-07-02</td><td>9999-01-01</td><td>null</td><td>Senior Staff</td><td>Initial Title</td><td>Current</td></tr><tr><td>100000</td><td>Hiroyasu Emden</td><td>1991-07-02</td><td>9999-01-01</td><td>Senior Staff</td><td>Senior Staff</td><td>No Change</td><td>Current</td></tr><tr><td>100001</td><td>Jasminko Antonakopoulos</td><td>1999-07-17</td><td>9999-01-01</td><td>null</td><td>Engineer</td><td>Initial Title</td><td>Current</td></tr><tr><td>100001</td><td>Jasminko Antonakopoulos</td><td>1999-07-17</td><td>9999-01-01</td><td>Engineer</td><td>Engineer</td><td>No Change</td><td>Current</td></tr><tr><td>100002</td><td>Claudi Kolinko</td><td>1988-02-20</td><td>9999-01-01</td><td>null</td><td>Senior Staff</td><td>Initial Title</td><td>Current</td></tr><tr><td>100002</td><td>Claudi Kolinko</td><td>1988-02-20</td><td>9999-01-01</td><td>Senior Staff</td><td>Senior Staff</td><td>No Change</td><td>Current</td></tr><tr><td>100003</td><td>Marsja Trogemann</td><td>1987-08-26</td><td>1995-08-26</td><td>null</td><td>Engineer</td><td>Initial Title</td><td>Exited</td></tr><tr><td>100003</td><td>Marsja Trogemann</td><td>1987-08-26</td><td>1995-08-26</td><td>Engineer</td><td>Engineer</td><td>No Change</td><td>Exited</td></tr><tr><td>100003</td><td>Marsja Trogemann</td><td>1995-08-26</td><td>1997-06-08</td><td>Engineer</td><td>Senior Engineer</td><td>Promoted</td><td>Exited</td></tr><tr><td>100003</td><td>Marsja Trogemann</td><td>1995-08-26</td><td>1997-06-08</td><td>Senior Engineer</td><td>Senior Engineer</td><td>No Change</td><td>Exited</td></tr><tr><td>100004</td><td>Avishai Nitsch</td><td>2000-01-11</td><td>9999-01-01</td><td>null</td><td>Staff</td><td>Initial Title</td><td>Current</td></tr><tr><td>100004</td><td>Avishai Nitsch</td><td>2000-01-11</td><td>9999-01-01</td><td>Staff</td><td>Staff</td><td>No Change</td><td>Current</td></tr><tr><td>100005</td><td>Anneke Foong</td><td>1999-08-10</td><td>9999-01-01</td><td>null</td><td>Staff</td><td>Initial Title</td><td>Current</td></tr><tr><td>100005</td><td>Anneke Foong</td><td>1999-08-10</td><td>9999-01-01</td><td>Staff</td><td>Staff</td><td>No Change</td><td>Current</td></tr><tr><td>100006</td><td>Janalee Himler</td><td>1986-01-15</td><td>1993-01-15</td><td>null</td><td>Engineer</td><td>Initial Title</td><td>Exited</td></tr><tr><td>100006</td><td>Janalee Himler</td><td>1986-01-15</td><td>1993-01-15</td><td>Engineer</td><td>Engineer</td><td>No Change</td><td>Exited</td></tr><tr><td>100006</td><td>Janalee Himler</td><td>1993-01-15</td><td>9999-01-01</td><td>Engineer</td><td>Senior Engineer</td><td>Promoted</td><td>Current</td></tr><tr><td>100006</td><td>Janalee Himler</td><td>1993-01-15</td><td>9999-01-01</td><td>Senior Engineer</td><td>Senior Engineer</td><td>No Change</td><td>Current</td></tr><tr><td>100007</td><td>Zine Bernardinello</td><td>1991-02-12</td><td>2000-02-12</td><td>null</td><td>Staff</td><td>Initial Title</td><td>Exited</td></tr><tr><td>100007</td><td>Zine Bernardinello</td><td>1991-02-12</td><td>2000-02-12</td><td>Staff</td><td>Staff</td><td>No Change</td><td>Exited</td></tr><tr><td>100007</td><td>Zine Bernardinello</td><td>2000-02-12</td><td>9999-01-01</td><td>Staff</td><td>Senior Staff</td><td>Promoted</td><td>Current</td></tr><tr><td>100007</td><td>Zine Bernardinello</td><td>2000-02-12</td><td>9999-01-01</td><td>Senior Staff</td><td>Senior Staff</td><td>No Change</td><td>Current</td></tr><tr><td>100008</td><td>Otmar Selvestrel</td><td>1988-03-20</td><td>1998-04-13</td><td>null</td><td>Senior Engineer</td><td>Initial Title</td><td>Exited</td></tr><tr><td>100008</td><td>Otmar Selvestrel</td><td>1988-03-20</td><td>1998-04-13</td><td> ...

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS employee_catalog.gold")
# Out:
# DataFrame[]

# %%
promotion_history_df.write \
    .option("mergeSchema", True) \
    .mode("overwrite") \
    .saveAsTable("employee_catalog.gold.promotion_history")

# %%
promotion_history_df.write \
    .format("parquet") \
    .mode("overwrite") \
    .save("mnt/gold/promotion_history")
